# %%
import pandas as pd
df1 = pd.read_csv('Auto.csv')
df1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0        8.0         307.0        130    3504          12.0    70
# 1  15.0        8.0         350.0        165    3693          11.5    70
# 2  18.0        NaN         318.0        150    3436          11.0    70
# 3  16.0        NaN         304.0        150    3433          12.0    70
# 4  17.0        8.0         302.0        140    3449           NaN    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# #### Setting Value

# %%
df1['new_col1'] = 1 
# to have a fixed value in all the rows
df1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0        8.0         307.0        130    3504          12.0    70
# 1  15.0        8.0         350.0        165    3693          11.5    70
# 2  18.0        NaN         318.0        150    3436          11.0    70
# 3  16.0        NaN         304.0        150    3433          12.0    70
# 4  17.0        8.0         302.0        140    3449           NaN    70
#
#    origin                       name  new_col1
# 0       1  chevrolet chevelle malibu         1
# 1       1          buick skylark 320         1
# 2       1         plymouth satellite         1
# 3       1              amc rebel sst         1
# 4       1                ford torino         1

# %%
df1['new_col2'] = df1['horsepower'] + df1['mpg']
df1.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     162 try:
# --> 163     result = func(left, right)
#     164 except TypeError:
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# ...

# %%
'a' + 'b' # str + str
# Out:
# 'ab'

# %%
10.5 + 10.2  # float + float
# Out:
# 20.7

# %%
'a' + 10.2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 'a' + 10.2
#
# TypeError: can only concatenate str (not "float") to str

# %%
df1[['mpg','horsepower']].dtypes
# Out:
# mpg           float64
# horsepower     object
# dtype: object

# %%
df1['mpg'] =  df1['mpg'].fillna(24) # random value
df1['cylinders'] =  df1['cylinders'].fillna(10) # random value

# %%
df1['new_column2'] = df1['mpg'] + df1['cylinders']
df1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0        8.0         307.0        130    3504          12.0    70
# 1  15.0        8.0         350.0        165    3693          11.5    70
# 2  18.0       10.0         318.0        150    3436          11.0    70
# 3  16.0       10.0         304.0        150    3433          12.0    70
# 4  17.0        8.0         302.0        140    3449           NaN    70
#
#    origin                       name  new_col1  new_column2
# 0       1  chevrolet chevelle malibu         1         26.0
# 1       1          buick skylark 320         1         23.0
# 2       1         plymouth satellite         1         28.0
# 3       1              amc rebel sst         1         26.0
# 4       1                ford torino         1         25.0

# %%
df1['new_col3'] = df1['cylinders'] ** 2
df1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0        8.0         307.0        130    3504          12.0    70
# 1  15.0        8.0         350.0        165    3693          11.5    70
# 2  18.0       10.0         318.0        150    3436          11.0    70
# 3  16.0       10.0         304.0        150    3433          12.0    70
# 4  17.0        8.0         302.0        140    3449           NaN    70
#
#    origin                       name  new_col1  new_column2  new_col3
# 0       1  chevrolet chevelle malibu         1         26.0      64.0
# 1       1          buick skylark 320         1         23.0      64.0
# 2       1         plymouth satellite         1         28.0     100.0
# 3       1              amc rebel sst         1         26.0     100.0
# 4       1                ford torino         1         25.0      64.0

# %% [markdown]
# #### Applying a function

# %%
'10' ** 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 '10' ** 2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
int('10') ** 2
# Out:
# 100

# %%
def hor_log(x):
    if x != '?':
        print(int(x)** 2)
    else:
        print(None)

# %%
df1['horsepower'].apply(hor_log)
# Out:
# 16900
# 27225
# 22500
# 22500
# 19600
# 39204
# 48400
# 46225
# 50625
# 36100
# 28900
# 25600
# 22500
# 50625
# 9025
# 9025
# 9409
# 7225
# 7744
# 2116
# 7569
# 8100
# 9025
# 12769
# 8100
# 46225
# 40000
# 44100
# 37249
# 7744
# 8100
# 9025
# None
# 10000
# 11025
# 10000
# 7744
# 10000
# 27225
# 30625
# 23409
# 22500
# 32400
# 28900
# 30625
# 12100
# 5184
# 10000
# 7744
# 7396
# 8100
# 4900
# 5776
# 4225
# 4761
# 3600
# 4900
# 9025
# 6400
# 2916
# 8100
# 7396
# 27225
# 30625
# 22500
# 23409
# 22500
# 43264
# 24025
# 25600
# 36100
# 9409
# 22500
# 16900
# 19600
# 22500
# 12544
# 5776
# 7569
# 4761
# 7396
# 8464
# 9409
# 6400
# 7744
# 30625
# 22500
# 21025
# 18769
# 22500
# 39204
# 22500
# 24964
# 22500
# 46225
# 50625
# 30625
# 11025
# 10000
# 10000
# 7744
# 9025
# 2116
# 22500
# 27889
# 28900
# 32400
# 10000
# 7744
# 5184
# 8836
# 8100
# 7225
# 11449
# 8100
# 21025
# 52900
# 2401
# 5625
# 8281
# 12544
# 22500
# 12100
# 14884
# 32400
# 9025
# None
# 10000
# 10000
# 4489
# 6400
# 4225
# ...

# %%
2 == 2 # Whether 2 is a match with 2 or not
# Out:
# True

# %%
2 == 20
# Out:
# False

# %%
2 != 20  # 2 is not equal to 20
# Out:
# True

# %%
# Lambda is used when you dont want to repeat the operation multiple times
# (Output for) (If)  (condition)  (else) (output for else) 
# brackets are for understanding

# %%
# df1['new_col4'] = df1['horsepower'].apply(lambda x: int(x) )

# %%
df1['new_col4'] = df1['horsepower'].apply(lambda x: int(x) ** 2 if x.isdigit() else None )
df1.head(40)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0   18.0        8.0         307.0        130    3504          12.0    70
# 1   15.0        8.0         350.0        165    3693          11.5    70
# 2   18.0       10.0         318.0        150    3436          11.0    70
# 3   16.0       10.0         304.0        150    3433          12.0    70
# 4   17.0        8.0         302.0        140    3449           NaN    70
# 5   15.0        8.0         429.0        198    4341           NaN    70
# 6   24.0        8.0         454.0        220    4354           9.0    70
# 7   24.0        8.0         440.0        215    4312           8.5    70
# 8   24.0        8.0         455.0        225    4425          10.0    70
# 9   24.0        8.0         390.0        190    3850           8.5    70
# 10  24.0        8.0         383.0        170    3563          10.0    70
# 11  24.0        8.0         340.0        160    3609           8.0    70
# ...

# %% [markdown]
# #### Sort by column

# %%
df1.sort_values(by = 'mpg', ascending=True)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 28    9.0        8.0         304.0        193    4732          18.5    70
# 26   10.0        8.0         307.0        200    4376          15.0    70
# 25   10.0        8.0         360.0        215    4615          14.0    70
# 27   11.0        8.0         318.0        210    4382          13.5    70
# 103  11.0        8.0         400.0        150    4997          14.0    73
# ..    ...        ...           ...        ...     ...           ...   ...
# 326  43.4        4.0          90.0         48    2335          23.7    80
# 393  44.0        4.0          97.0         52    2130          24.6    82
# 325  44.3        4.0          90.0         48    2085          21.7    80
# 329  44.6        4.0          91.0         67    1850          13.8    80
# 322  46.6        4.0          86.0         65    2110          17.9    80
#
#      origin                  name  new_col1  new_column2  new_col3  new_col4
# ...

# %% [markdown]
# #### Filtering the dataset using condition

# %%
df1[ (df1['mpg'] < 25) ]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0        8.0         307.0        130    3504          12.0    70
# 1    15.0        8.0         350.0        165    3693          11.5    70
# 2    18.0       10.0         318.0        150    3436          11.0    70
# 3    16.0       10.0         304.0        150    3433          12.0    70
# 4    17.0        8.0         302.0        140    3449           NaN    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 363  22.4        6.0         231.0        110    3415          15.8    81
# 365  20.2        6.0         200.0         88    3060          17.1    81
# 366  17.6        6.0         225.0         85    3465          16.6    81
# 373  24.0        4.0         140.0         92    2865          16.4    82
# 388  22.0        6.0         232.0        112    2835          14.7    82
#
#      origin                       name  new_col1  new_column2  new_col3  \
# ...

# %%
df1[ (df1['mpg'] < 25) & (df1['cylinders'] == 8) ]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0        8.0         307.0        130    3504          12.0    70
# 1    15.0        8.0         350.0        165    3693          11.5    70
# 4    17.0        8.0         302.0        140    3449           NaN    70
# 5    15.0        8.0         429.0        198    4341           NaN    70
# 6    24.0        8.0         454.0        220    4354           9.0    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 290  15.5        8.0         351.0        142    4054          14.3    79
# 291  19.2        8.0         267.0        125    3605          15.0    79
# 292  18.5        8.0         360.0        150    3940          13.0    79
# 298  23.0        8.0         350.0        125    3900          17.4    79
# 300  23.9        8.0         260.0         90    3420          22.2    79
#
#      origin                                  name  new_col1  new_column2  \
# ...
